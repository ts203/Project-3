# %% [markdown]
# ### Jincy Njenga
# > INST326 Section 0202
# > Group 38
# > Project 3
# > Date Due: November 22, 2024
# > Pin: 1005
# #### Honor Pledge
# > I pledge that the work contained in this assignment is my own and I pledge on my honor that I have not given or received any unathorized assitance on this exam/assignment. -- Jincy Njenga
# #### Disclosures
# > None.

# %% [markdown]
# ### Aritro
# > INST326 Section 0202
# > Group 38
# > Project 3
# > Date Due: November 22, 2024
# > Pin:
# #### Honor Pledge
# > I pledge that the work contained in this assignment is my own and I pledge on my honor that I have not given or received any unathorized assitance on this exam/assignment. -- Aritro
# #### Disclosures
# > None.

# %% [markdown]
# ### Tanushree Sharma
# > INST326 Section 0202
# > Group 38
# > Project 3
# > Date Due: November 22, 2024
# > Pin: 2003
# #### Honor Pledge
# > I pledge that the work contained in this assignment is my own and I pledge on my honor that I have not given or received any unathorized assitance on this exam/assignment. -- Tanushree Sharma
# #### Disclosures
# > None.

# %%
#Created by Jincy
# caregiver class
class Caregiver:
    caregivers_availability = {}

    def __init__(self, name, phone, email, payrate, hours):
        self.name = name
        self.phone = phone
        self.email = email
        self.payrate = payrate
        self.hours = hours
        self.am = {}
        self.pm = {}
        
# Created by Jincy
    def set_preferences(self):
        days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
        for day in days:
            # user inserts availability for AM and PM Sunday through Saturday
            availability_am = input(f"What is your availability for {day} am?: ")
            self.am[day] = availability_am
            availability_pm = input(f"What is your availability for {day} pm?: ")
            self.pm[day] = availability_pm
        #created by Aritro
        Caregiver.caregivers_availability[self.name] = {"am": self.am, "pm": self.pm}

#Created by Jincy
    def weekly_schedule(self):          
            schedule = f"""
            <html>
            <head>
                <title>Weekly work Schedule for {self.name}</title>
                <style>
                    table {{
                        border-collapse: collapse;
                        width: 100%;
                        margin: 20px 0;
                    }}
                    th, td {{
                        border: 1px solid black;
                        padding: 10px;
                        text-align: center;
                    }}
                    th {{
                        background-color: #f2f2f2;
                    }}
                    td {{
                        height: 100px;
                        vertical-align: top;
                    }}
                </style>
            </head>
            <body>
                <h1>Weekly availability for {self.name}</h1>
                <table>
                    <tr>
                        <th>Mon</th>
                        <th>Tue</th>
                        <th>Wed</th>
                        <th>Thu</th>
                        <th>Fri</th>
                        <th>Sat</th>
                        <th>Sun</th>
                    </tr>
                    <tr>
                    
                        <td>am: {self.am["monday"]}</td>
                        <td>am: {self.am["tuesday"]} </td>
                        <td>am: {self.am["wednesday"]} </td>
                        <td>am: {self.am["thursday"]}</td>
                        <td>am: {self.am["friday"]} </td>
                        <td>am: {self.am["saturday"]} </td>
                        <td>am: {self.am["sunday"]}</td>
                    </tr>
                    <tr>
                        <td>pm: {self.pm["monday"]}</td>
                        <td>pm: {self.pm["tuesday"]} </td>
                        <td>pm: {self.pm["wednesday"]} </td>
                        <td>pm: {self.pm["thursday"]}</td>
                        <td>pm: {self.pm["friday"]} </td>
                        <td>pm: {self.pm["saturday"]} </td>
                        <td>pm: {self.pm["sunday"]}</td>

                    </tr>

                </table>
    
                    
            """
            # creates weekly availability schedule for each caregiver
            with open(f"Weekly Work Schedule For {self.name}.html", "w") as file:
                file.write(schedule)
            # lets user know that a file has been created
            print("generating work schedule")

        
#Created by Aritro
    def generate_calendar():
        calendar = {}
        for caregiver, availability in Caregiver.caregivers_availability.items():
            for day, time in availability["am"].items():
                if day not in calendar:
                    calendar[day] = {"am": [], "pm": []}
                if time in ["available", "preferred"]:
                    calendar[day]["am"].append(f"{caregiver} ({time})")
            for day, time in availability["pm"].items():
                if time in ["available", "preferred"]:
                    calendar[day]["pm"].append(f"{caregiver} ({time})")
        return calendar

# caregiver object
anne = Caregiver("anne", "443-891-3933", "anne@gmail.com", 20, 10)
anne.set_preferences()
anne.weekly_schedule()


#Created by Aritro
consolidated_calendar = Caregiver.generate_calendar()
print("Consolidated Calendar:")
for day, times in consolidated_calendar.items():
    print(f"{day.capitalize()} - AM: {', '.join(times['am'])} | PM: {', '.join(times['pm'])}")
    
#Created by Tanushree
class Pay(Caregiver):
    def __init__(self, caregivers):
        self.caregivers = caregivers

    def calculate_weekly_hours_and_pay(self):
        weekly_summary = {}
        for caregiver in self.caregivers:
            total_hours = 0
            # Each shift (AM or PM) counts as 6 hours
            shift_hours = 6
            for day in caregiver.am.keys():
                if caregiver.am[day] in ["available", "preferred"]:
                    total_hours += shift_hours
                if caregiver.pm[day] in ["available", "preferred"]:
                    total_hours += shift_hours
            caregiver.hours = total_hours
            weekly_pay = total_hours * caregiver.payrate
            weekly_summary[caregiver.name] = {"hours": total_hours, "pay": weekly_pay}
        return weekly_summary

#Created by Aritro
#Instantiate caregivers
anne = Caregiver("anne", "443-891-3933", "anne@gmail.com", 20, 10)
anne.set_preferences()

john = Caregiver("john", "301-287-5690", "john@gmail.com", 25, 15)
john.set_preferences()

#Consolidate calendar (from earlier code)
consolidated_calendar = Caregiver.generate_calendar()
print("Consolidated Calendar:")
for day, times in consolidated_calendar.items():
    print(f"{day.capitalize()} - AM: {', '.join(times['am'])} | PM: {', '.join(times['pm'])}")
    
#Created by Tanushree 
#Calculate weekly pay
caregivers = [anne, john]
pay_calculator = Pay(caregivers)
weekly_summary = pay_calculator.calculate_weekly_hours_and_pay()

#Display weekly summary
print("\nWeekly Pay Summary:")
for caregiver, summary in weekly_summary.items():
    print(f"{caregiver}: {summary['hours']} hours worked, ${summary['pay']} earned")
# Out:
# What is your availability for monday am?: unavailable
# What is your availability for monday pm?: available
# What is your availability for tuesday am?: available
# What is your availability for tuesday pm?: unavailable
# What is your availability for wednesday am?: available
# What is your availability for wednesday pm?: available
# What is your availability for thursday am?: unavailable
# What is your availability for thursday pm?: unavailable
# What is your availability for friday am?: available
# What is your availability for friday pm?: unavailable
# What is your availability for saturday am?: unavailable
# What is your availability for saturday pm?: available
# What is your availability for sunday am?: available
# What is your availability for sunday pm?: available
# generating work schedule
# Consolidated Calendar:
# Monday - AM:  | PM: anne (available)
# Tuesday - AM: anne (available) | PM:
# Wednesday - AM: anne (available) | PM: anne (available)
# Thursday - AM:  | PM:
# Friday - AM: anne (available) | PM:
# Saturday - AM:  | PM: anne (available)
# Sunday - AM: anne (available) | PM: anne (available)
# What is your availability for monday am?: available
# What is your availability for monday pm?: available
# What is your availability for tuesday am?: unavailable
# What is your availability for tuesday pm?: unavailable
# What is your availability for wednesday am?: available
# What is your availability for wednesday pm?: unavailable
# What is your availability for thursday am?: available
# What is your availability for thursday pm?: available
# What is your availability for friday am?: available
# What is your availability for friday pm?: available
# What is your availability for saturday am?: available
# What is your availability for saturday pm?: unavailable
# What is your availability for sunday am?: unavailable
# What is your availability for sunday pm?: unavailable
# What is your availability for monday am?: available
# What is your availability for monday pm?: unavailable
# What is your availability for tuesday am?: available
# What is your availability for tuesday pm?: available
# What is your availability for wednesday am?: available
# What is your availability for wednesday pm?: unavailable
# What is your availability for thursday am?: unavailable
# What is your availability for thursday pm?: available
# What is your availability for friday am?: unavailable
# What is your availability for friday pm?: available
# What is your availability for saturday am?: unavailable
# What is your availability for saturday pm?: available
# What is your availability for sunday am?: available
# What is your availability for sunday pm?: available
# Consolidated Calendar:
# Monday - AM: anne (available), john (available) | PM: anne (available)
# Tuesday - AM: john (available) | PM: john (available)
# Wednesday - AM: anne (available), john (available) | PM:
# Thursday - AM: anne (available) | PM: anne (available), john (available)
# Friday - AM: anne (available) | PM: anne (available), john (available)
# Saturday - AM: anne (available) | PM: john (available)
# Sunday - AM: john (available) | PM: john (available)
#
# Weekly Pay Summary:
# anne: 48 hours worked, $960 earned
# john: 54 hours worked, $1350 earned
