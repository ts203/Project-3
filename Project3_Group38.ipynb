# %%
Jincy Njenga

INST326 Section 0202 Group number / name if applicable Assignment: Lab0506 Date Due: 10/06/2024 PIN 1005

Honor Pledge

I pledge that the work contained in this assignment is my own work and I pledge on my honor that I have not given or received any unathorized assitance on this exam/assignment. -- Jincy Njenga

Disclosures

None.

# %%
Aritro Signature Block

# %%
Tanushree Sharma

INST326 Section 0202 Group number 38 Assignment: Project 3 Date Due: 11/22/2024 PIN 2003

Honor Pledge

I pledge that the work contained in this assignment is my own work and I pledge on my honor that I have not given or received any unathorized assitance on this exam/assignment. -- Tanushree Sharma

Disclosures

None.

# %%
Github Link: https://github.com/AritroGomes/Project-3

# %%
#Created by Jincy
# caregiver class
class Caregiver:
    caregivers_availability = {}

    def __init__(self, name, phone, email, payrate, hours):
        self.name = name
        self.phone = phone
        self.email = email
        self.payrate = payrate
        self.hours = hours
        self.am = {}
        self.pm = {}
        
# Created by Jincy
    def set_preferences(self):
        days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
        for day in days:
            # user inserts availability for AM and PM Sunday through Saturday
            availability_am = input(f"What is your availability for {day} am?: ")
            self.am[day] = availability_am
            availability_pm = input(f"What is your availability for {day} pm?: ")
            self.pm[day] = availability_pm
        #created by Aritro
        Caregiver.caregivers_availability[self.name] = {"am": self.am, "pm": self.pm}

#Created by Jincy
    def weekly_schedule(self):          
            schedule = f"""
            <html>
            <head>
                <title>Weekly work Schedule for {self.name}</title>
                <style>
                    table {{
                        border-collapse: collapse;
                        width: 100%;
                        margin: 20px 0;
                    }}
                    th, td {{
                        border: 1px solid black;
                        padding: 10px;
                        text-align: center;
                    }}
                    th {{
                        background-color: #f2f2f2;
                    }}
                    td {{
                        height: 100px;
                        vertical-align: top;
                    }}
                </style>
            </head>
            <body>
                <h1>Weekly availability for {self.name}</h1>
                <table>
                    <tr>
                        <th>Mon</th>
                        <th>Tue</th>
                        <th>Wed</th>
                        <th>Thu</th>
                        <th>Fri</th>
                        <th>Sat</th>
                        <th>Sun</th>
                    </tr>
                    <tr>
                    
                        <td>am: {self.am["monday"]}</td>
                        <td>am: {self.am["tuesday"]} </td>
                        <td>am: {self.am["wednesday"]} </td>
                        <td>am: {self.am["thursday"]}</td>
                        <td>am: {self.am["friday"]} </td>
                        <td>am: {self.am["saturday"]} </td>
                        <td>am: {self.am["sunday"]}</td>
                    </tr>
                    <tr>
                        <td>pm: {self.pm["monday"]}</td>
                        <td>pm: {self.pm["tuesday"]} </td>
                        <td>pm: {self.pm["wednesday"]} </td>
                        <td>pm: {self.pm["thursday"]}</td>
                        <td>pm: {self.pm["friday"]} </td>
                        <td>pm: {self.pm["saturday"]} </td>
                        <td>pm: {self.pm["sunday"]}</td>

                    </tr>

                </table>
    
                    
            """
            # creates weekly availability schedule for each caregiver
            with open(f"Weekly Work Schedule For {self.name}.html", "w") as file:
                file.write(schedule)
            # lets user know that a file has been created
            print("generating work schedule")

        
#Created by Aritro
    def generate_calendar():
        calendar = {}
        for caregiver, availability in Caregiver.caregivers_availability.items():
            for day, time in availability["am"].items():
                if day not in calendar:
                    calendar[day] = {"am": [], "pm": []}
                if time in ["available", "preferred"]:
                    calendar[day]["am"].append(f"{caregiver} ({time})")
            for day, time in availability["pm"].items():
                if time in ["available", "preferred"]:
                    calendar[day]["pm"].append(f"{caregiver} ({time})")
        return calendar

# caregiver object
anne = Caregiver("anne", "443-891-3933", "anne@gmail.com", 20, 10)
anne.set_preferences()
anne.weekly_schedule()


#Created by Aritro
consolidated_calendar = Caregiver.generate_calendar()
print("Consolidated Calendar:")
for day, times in consolidated_calendar.items():
    print(f"{day.capitalize()} - AM: {', '.join(times['am'])} | PM: {', '.join(times['pm'])}")
# Out:
# What is your availability for monday am?:  a
# What is your availability for monday pm?:  a
# What is your availability for tuesday am?:  a
# What is your availability for tuesday pm?:  a
# What is your availability for wednesday am?:  a
# What is your availability for wednesday pm?:  a
# What is your availability for thursday am?:  a
# What is your availability for thursday pm?:  a
# What is your availability for friday am?:  a
# What is your availability for friday pm?:  a
# What is your availability for saturday am?:  a
# What is your availability for saturday pm?:  a
# What is your availability for sunday am?:  a
# What is your availability for sunday pm?:  a
# generating work schedule
# Consolidated Calendar:
# Monday - AM:  | PM:
# Tuesday - AM:  | PM:
# Wednesday - AM:  | PM:
# Thursday - AM:  | PM:
# Friday - AM:  | PM:
# Saturday - AM:  | PM:
# Sunday - AM:  | PM:
